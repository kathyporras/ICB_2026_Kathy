# %%
print ("hello world")
# Out:
# hello world

# %%
1 + 5
# Out:
# 6

# %%
4 * 5 # multiplication
# Out:
# 20

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10//3
# Out:
# 3

# %%
10%3
# Out:
# 1

# %%
3**3
# Out:
# 27

# %%
3 + 5 * 2
# Out:
# 13

# %%
(3 + 5) * 2
# Out:
# 16

# %%
3 > 5
# Out:
# False

# %%
3 < 5
# Out:
# True

# %%
2+2 == 6 #here I used two equals because if not it will assigned a variable
# Out:
# False

# %%
2 + 2 != 6 #not equals to
# Out:
# True

# %%
x = 5 #setting variables

# %%
x
# Out:
# 5

# %%
who #what variables are there
# Out:
# No variables match your requested type.

# %%
y = "a"

# %%
who
# Out:
# x	 y

# %%
x + 2
# Out:
# 7

# %%
y = 3

# %%
x+y
# Out:
# 8

# %%
# you can have variables as numbers or letters and they participate in functions just like school

# %%
x
# Out:
# 5

# %%
type(x) #number with no decimals int
# Out:
# int

# %%
height = 1.81

# %%
type(height) #float numbers with decimals
# Out:
# float

# %%
type(1.0000000)
# Out:
# float

# %%
type(1)
# Out:
# int

# %%
abs(-2.3)
# Out:
# 2.3

# %%
pow(3, 6)
# Out:
# 729

# %%
3**6
# Out:
# 729

# %%
round(5.444232242323, 2) # rounded to two decimal points
# Out:
# 5.44

# %%
Open = True

# %%
type(Open)
# Out:
# bool

# %%
Open = False

# %%
type(Open)
# Out:
# bool

# %%
Open + Open #in case you want to know how many trues there were for example ignoring the false part
# Out:
# 2

# %%
seq = "AGGCTCCGA"

# %%
myname = "Kathy Porras" #character string

# %%
myname
# Out:
# 'Kathy Porras'

# %%
print(seq)
# Out:
# AGGCTCCGA

# %%
print("my name is", myname)
# Out:
# my name is Kathy Porras

# %%
print("my name is", myname, sep= ", ")
# Out:
# my name is, Kathy Porras

# %%
len(seq) #how many letter does your sring have
# Out:
# 9

# %%
seq.count("G")
# Out:
# 3

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
help(seq.count) #let you know which functions apply for your specific case and variable
# Out:
# Help on built-in function count:
#
# count(sub[, start[, end]], /) method of builtins.str instance
#     Return the number of non-overlapping occurrences of substring sub in string S[start:end].
#
#     Optional arguments start and end are interpreted as in slice
#     notation.

# %%
seq.replace("T", "U")
# Out:
# 'AGGCUCCGA'

# %%
#you can set this as a variable
rna_seq = seq.replace("T", "U")

# %%
rna_seq
# Out:
# 'AGGCUCCGA'

# %%
seq.find("T") #first time that T appears in he fourth place for the first time
# Out:
# 4

# %%
myname.split() #you need spaces in yout string that's why it doesnt work in your sequence
# Out:
# ['Kathy', 'Porras']

# %%
myname.split("P")
# Out:
# ['Kathy ', 'orras']

# %%
upstream = "AAATA"
downstream = "CTTC"
promoter = "TAGCCTA"

# %%
upstream+ "-"+promoter + "-" + downstream
# Out:
# 'AAATA-TAGCCTA-CTTC'

# %%
#class exercises
s = "WHEN on board H.M.S Beagle, as natura-list"

# %%
s.count("b")
# Out:
# 1

# %%
s.replace("WHEN", "When")
# Out:
# 'When on board H.M.S Beagle, as natura-list'

# %%
s.count("b")+s.count("B") #count both at the same time
# Out:
# 2

# %%
mylist = ["ATTA", 25, 3.4, True]

# %%
mylist
# Out:
# ['ATTA', 25, 3.4, True]

# %%
mylist[0] #show me the first element and they start counting in 0
# Out:
# 'ATTA'

# %%
mylist[3]
# Out:
# True

# %%
mylist[1:3] #exclunding the third one
# Out:
# [25, 3.4]

# %%
mylist[1:] #including the final
# Out:
# [25, 3.4, True]

# %%
mylist[-1] #reverse and in reverse they dont start from zero
# Out:
# True

# %%
mylist[-2:]
# Out:
# [3.4, True]

# %%
mylist[3]=False

# %%
mylist
# Out:
# ['ATTA', 25, 3.4, False]

# %%
del(mylist[3]) #removing a component of my string

# %%
mylist
# Out:
# ['ATTA', 25, 3.4]

# %%
gene = list("ACGTACGT")

# %%
gene.count("G")
# Out:
# 2

# %%
gene.append("p") #we added a last p in the string of the list

# %%
gene
# Out:
# ['A', 'C', 'G', 'T', 'A', 'C', 'G', 'T', 'p', 'p']

# %%
gene.index("T") #tell me in which position is it in the first time and remember starts counting from 0
# Out:
# 3

# %%
a = [4,2,5,6,3]

# %%
a
# Out:
# [4, 2, 5, 6, 3]

# %%
a.sort()

# %%
a
# Out:
# [2, 3, 4, 5, 6]

# %%
a.reverse()

# %%
a
# Out:
# [6, 5, 4, 3, 2]

# %%
a = (4,2,5,6,3) #now it's a tuple

# %%
type(a)
# Out:
# tuple

# %%
a[2]
# Out:
# 5

# %%
a[2] = 4 #you cannot change anything from a tuple! because sometimes we dont want to mess up variables so we can make it a tuple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 a[2] = 4 #you cannot change anything from a tuple!
#
# TypeError: 'tuple' object does not support item assignment

# %%
a.count(4)
# Out:
# 1

# %%
a.index(2)
# Out:
# 1

# %%
dict = {"a":"test", "b":55, "c":[1,2,3]} #creating a dictionary with curly parenthesis

# %%
dict
# Out:
# {'a': 'test', 'b': 55, 'c': [1, 2, 3]}

# %%
type(dict)
# Out:
# dict

# %%
cases = {"Riner":10,
         "Christianburg":25,
         "Blacksburg":34}

# %%
cases
# Out:
# {'Riner': 10, 'Christianburg': 25, 'Blacksburg': 34}

# %%
cases["Blacksburg"]
# Out:
# 34

# %%
cases["Merrimac"]=3 #adding a piece of the dictionary

# %%
cases
# Out:
# {'Riner': 10, 'Christianburg': 25, 'Blacksburg': 34, 'Merrimac': 3}

# %%
cases["Merrimac"] = 13 #correcting your dictionary

# %%
cases
# Out:
# {'Riner': 10, 'Christianburg': 25, 'Blacksburg': 34, 'Merrimac': 13}

# %%
cases.get("Blacksburg", "Not found") #find it and let me know if its not found
# Out:
# 34

# %%
cases.get("Rocky Mount", "Not found") #assess especific things from our dictionaries
# Out:
# 'Not found'

# %%
cases.keys() #the things that were between "" in your dictionary
# Out:
# dict_keys(['Riner', 'Christianburg', 'Blacksburg', 'Merrimac'])

# %%
cases.values() #the number from your dictionaries
# Out:
# dict_values([10, 25, 34, 13])

# %%
cases2 = {"Rocky Mount":32, "Riner":9}

# %%
cases.update(cases2) #fix my errors! and order matters.

# %%
cases
# Out:
# {'Riner': 9,
#  'Christianburg': 25,
#  'Blacksburg': 34,
#  'Merrimac': 13,
#  'Rocky Mount': 32}

# %%
#class exercises
a = [1,1,2,3,5,8]

# %%
a
# Out:
# [1, 1, 2, 3, 5, 8]

# %%
a[4:]
# Out:
# [5, 8]

# %%
a[-2:]
# Out:
# [5, 8]

# %%
a.append(13)

# %%
a
# Out:
# [1, 1, 2, 3, 5, 8, 13]

# %%
a.reverse()

# %%
a
# Out:
# [13, 8, 5, 3, 2, 1, 1]

# %%
m = {"a": ".-", "b": "-..-", "c": "-.-."}

# %%
m
# Out:
# {'a': '.-', 'b': '-..-', 'c': '-.-.'}

# %%
m ["d"] = "-.." #adding another variable to the dictionary

# %%
m
# Out:
# {'a': '.-', 'b': '-..-', 'c': '-.-.', 'd': '-..'}

# %%
#end of the class exercises.
a= [5,6,7,7,7,8,9,9]

# %%
max(a)
# Out:
# 9

# %%
b=["Computational", "Biology", "BIOL 2214"]

# %%
max(b)
# Out:
# 'Computational'

# %%
c = "BIOL2214 Intro"

# %%
max(c)
# Out:
# 't'

# %%
"-".join(b)
# Out:
# 'Computational-Biology-BIOL 2214'

# %%
"".join(b)
# Out:
# 'ComputationalBiologyBIOL 2214'

# %%
"B" in c #it didnt work in b because is a list
# Out:
# True

# %%
dict
# Out:
# {'a': 'test', 'b': 55, 'c': [1, 2, 3]}

# %%
"a" in dict
# Out:
# True

# %%
55 in dict.values() #is 55 in this list of things?
# Out:
# True
